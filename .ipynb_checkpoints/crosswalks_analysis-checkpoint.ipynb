# %%
import pandas as pd
import geopandas
import numpy as np

# %matplotlib inline

# load data
crosswalks = pd.read_csv("crosswalks_and_neighborhoods.csv", 
                                       index_col="_id") # use the column named _id as the row index

# %%
crosswalks.head(10)
# Out:
#              id                     type           street inactive  \
# _id
# 1    1559483633        Crosswalk - Other      ELEVENTH ST        f
# 2     785965942    Crosswalk - Two Lined         PENN AVE        f
# 3    2008474459    Crosswalk - Two Lined  MORNINGSIDE AVE        f
# 4    1207933462    Crosswalk - Two Lined          TECH ST        f
# 5     905740180    Crosswalk - Two Lined          FREW ST        f
# 6     768755224    Crosswalk - Two Lined       FORBES AVE        f
# 7    1308677189    Crosswalk - Two Lined        BEELER ST        f
# 8    1159710354    Crosswalk - Two Lined        BEELER ST        f
# 9     216672403  Crosswalk - Continental       FORBES AVE        f
# 10    356629441  Crosswalk - Continental        FIFTH AVE        f
#
#                   neighborhood  council_district  ward        tract  \
# _id
# 1    Central Business District               6.0   2.0  42003020100
# 2               Strip District               7.0   2.0  42003020300
# 3                  Morningside               7.0  10.0  42003101400
# 4          Squirrel Hill North               8.0  14.0  42003140100
# 5          Squirrel Hill South               5.0  14.0  42003980500
# 6          Squirrel Hill North               8.0  14.0  42003140100
# 7          Squirrel Hill North               8.0  14.0  42003140100
# 8          Squirrel Hill North               8.0  14.0  42003140100
# 9          Squirrel Hill North               8.0  14.0  42003140100
# 10                   Shadyside               8.0  14.0  42003140100
#
#      public_works_division  pli_division  police_zone fire_zone   latitude  \
# _id
# 1                      6.0           2.0          2.0       2-3  40.444989
# 2                      6.0           2.0          2.0       2-3  40.445717
# 3                      2.0          10.0          5.0       3-7  40.479579
# 4                      3.0          14.0          4.0       2-8  40.440528
# 5                      3.0          14.0          4.0       2-8  40.440468
# 6                      3.0          14.0          4.0      2-26  40.443852
# 7                      3.0          14.0          4.0      2-26  40.443965
# 8                      3.0          14.0          4.0      2-26  40.445632
# 9                      3.0          14.0          4.0       2-9  40.444583
# 10                     2.0          14.0          4.0      2-26  40.447427
#
#      longitude
# _id
# 1   -79.993884
# 2   -79.992465
# 3   -79.930685
# 4   -79.942126
# 5   -79.942267
# 6   -79.939028
# 7   -79.938673
# 8   -79.931342
# 9   -79.945557
# 10  -79.942548

# %%
#query_mask = crosswalks_pandas["type"] == 

#crosswalks_pandas.pivot(columns="neighborhood", values="type").head()
#crosswalks_pandas.plot()

# finds the total number of crosswalks for each neighborhood
neigh_dict = {}
cross_types_dict = {}
bricks_dict = {}

for index, row in crosswalks.iterrows():
    neigh_name = row["neighborhood"]
    cross_name = row["type"]
    
    # if the neighborhood is not in the dictionary, set it equal to 1
    if (neigh_name not in neigh_dict):
        neigh_dict[neigh_name] = 1
        # if the crosswalk found is brick, adds it to the bricks dictionary (key=neighborhood, value=quantity)
        if ("Brick" in cross_name):
            bricks_dict[neigh_name] = 1
    # else, if the item already exists in the dictionary add 1
    elif (neigh_name in neigh_dict):
        neigh_dict[neigh_name] += 1
        # if the crosswalk found is brick, adds 1 to the bricks dictionary (key=neighborhood, value=quantity)
        if ("Brick" in cross_name):
            if (neigh_name not in bricks_dict):
                bricks_dict[neigh_name] = 1
            elif (neigh_name in bricks_dict):
                bricks_dict[neigh_name] += 1

# finds how many times each type of crosswalk appears
for index, row in crosswalks.iterrows():
    cross_name = row["type"]
    
    # if the neighborhood is not in the dictionary, set it equal to 1
    if (cross_name not in cross_types_dict):
        cross_types_dict[cross_name] = 1
    # else, if the item already exists in the dictionary add 1
    elif (cross_name in cross_types_dict):
        cross_types_dict[cross_name] += 1
        
        
print(neigh_dict)
print("\n")
print(cross_types_dict)
print("\n")
print(bricks_dict)
# Out:
# {'Central Business District': 402, 'Strip District': 114, 'Morningside': 33, 'Squirrel Hill North': 112, 'Squirrel Hill South': 239, 'Shadyside': 190, 'Polish Hill': 29, 'North Oakland': 125, 'West Oakland': 41, 'Central Oakland': 113, 'East Liberty': 146, 'Bloomfield': 192, 'South Oakland': 66, 'Stanton Heights': 22, 'Terrace Village': 67, 'Highland Park': 64, 'Bluff': 82, 'Lincoln-Lemington-Belmar': 29, 'Lincoln Place': 15, 'Lower Lawrenceville': 40, 'Crawford-Roberts': 63, 'Middle Hill': 59, 'Bedford Dwellings': 8, 'Upper Hill': 21, 'Point Breeze': 91, 'Larimer': 58, 'Point Breeze North': 53, 'Homewood West': 20, 'Homewood North': 40, 'Homewood South': 81, 'East Hills': 21, nan: 14, 'Friendship': 37, 'Regent Square': 15, 'South Side Flats': 262, 'South Shore': 15, 'Swisshelm Park': 7, 'Greenfield': 68, 'Hazelwood': 68, 'Glen Hazel': 7, 'Elliott': 25, 'Hays': 7, 'Esplen': 15, 'New Homestead': 1, 'Central Lawrenceville': 81, 'West End': 24, 'Troy Hill': 40, 'East Allegheny': 60, 'Spring Garden': 6, 'North Shore': 75, 'Spring Hill-City View': 18, 'Summer Hill': 3, 'Northview Heights': 18, 'Perry North': 43, 'Allegheny Center': 41, 'Central Northside': 45, 'Garfield': 55, 'Chateau': 29, 'Manchester': 50, 'California-Kirkbride': 15, 'Allegheny West': 26, 'Perry South': 65, 'Fineview': 3, 'Marshall-Shadeland': 29, 'Brighton Heights': 62, 'Windgap': 11, 'Fairywood': 3, 'Sheraden': 35, 'Crafton Heights': 17, 'Chartiers City': 1, 'Westwood': 11, 'Oakwood': 8, 'Duquesne Heights': 24, 'Mount Washington': 95, 'Allentown': 24, 'Beltzhoover': 32, 'South Side Slopes': 31, 'Arlington': 13, 'Knoxville': 40, 'Carrick': 73, 'Bon Air': 12, 'Brookline': 86, 'Overbrook': 31, 'Beechview': 69, 'Banksville': 16, 'Mt. Oliver': 8, 'Mount Oliver Borough': 8, 'St. Clair': 1, 'Upper Lawrenceville': 34}
#
#
# {'Crosswalk - Other': 10, 'Crosswalk - Two Lined': 3457, 'Crosswalk - Continental': 703, 'Crosswalk - Ladder': 284, 'Crosswalk - Brick and Markings': 125, 'Crosswalk - Brick Only': 69}
#
#
# {'Central Business District': 152, 'North Shore': 31, 'Chateau': 3, 'South Side Flats': 8}

# %%
# total neighborhoods for the only 4 neighborhoods with brick crosswalks
totals_dict = {}
totals_dict["Central Business District"] = neigh_dict["Central Business District"]
totals_dict["North Shore"] = neigh_dict["North Shore"]
totals_dict["Chateau"] = neigh_dict["Chateau"]
totals_dict["South Side Flats"] = neigh_dict["South Side Flats"]

print(totals_dict)
# Out:
# {'Central Business District': 402, 'North Shore': 75, 'Chateau': 29, 'South Side Flats': 262}

# %%
# proportion of each neighborhoods brick to total crosswalks
prop_dict = {}
prop_dict["Central Business District"] = bricks_dict["Central Business District"] / totals_dict["Central Business District"]
prop_dict["North Shore"] = bricks_dict["North Shore"] / totals_dict["North Shore"]
prop_dict["Chateau"] = bricks_dict["Chateau"] / totals_dict["Chateau"]
prop_dict["South Side Flats"] = bricks_dict["South Side Flats"] / totals_dict["South Side Flats"]

print(prop_dict)
# Out:
# {'Central Business District': 0.3781094527363184, 'North Shore': 0.41333333333333333, 'Chateau': 0.10344827586206896, 'South Side Flats': 0.030534351145038167}

# %%
#creates a dataframe 

#num_crosswalks = crosswalks.groupby
neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp") # read in the shapefile
neighborhoods.plot() # plot the geopandas dataframe
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Neighborhoods/Neighborhoods_.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-9-6370522c2e8b> in <module>
#       2
#       3 #num_crosswalks = crosswalks.groupby
# ----> 4 neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp") # read in the shapefile
#       5 neighborhoods.plot() # plot the geopandas dataframe
#
# /opt/tljh/user/lib/python3.8/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#      94
#      95     with fiona_env():
# ---> 96         with reader(path_or_bytes, **kwargs) as features:
#      97
#      98             # In a future Fiona release the crs attribute of features will
#
# /opt/tljh/user/lib/python3.8/site-packages/fiona/env.py in wrapper(*args, **kwargs)
#     396     def wrapper(*args, **kwargs):
#     397         if local._env:
# --> 398             return f(*args, **kwargs)
#     399         else:
#     400             if isinstance(args[0], str):
#
# /opt/tljh/user/lib/python3.8/site-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     251
#     252         if mode in ('a', 'r'):
# --> 253             c = Collection(path, mode, driver=driver, encoding=encoding,
#     254                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     255         elif mode == 'w':
#
# /opt/tljh/user/lib/python3.8/site-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     152             if self.mode == 'r':
#     153                 self.session = Session()
# --> 154                 self.session.start(self, **kwargs)
#     155             elif self.mode in ('a', 'w'):
#     156                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: Neighborhoods/Neighborhoods_.shp: No such file or directory
